# %%
import matplotlib.pyplot as plt
import numpy as np

# Provided data
labels = ['Python', 'Java']

# Time for each sorting algorithm
merge_sort_times = [890195.77, 497249]
quick_sort_times = [735394.03, 483405]

x = np.arange(len(labels))  # Label locations
width = 0.35  # Width of the bars

plt.figure(figsize=(10, 6))

# Plot bars
plt.bar(x - width/2, merge_sort_times, width, label='Merge Sort', color='skyblue', edgecolor='black')
plt.bar(x + width/2, quick_sort_times, width, label='Quick Sort', color='orange', edgecolor='black')

# Labels and title
plt.xlabel('Language')
plt.ylabel('Time (ms)')
plt.title('Merge Sort vs Quick Sort Time Comparison(Python vs Java)')
plt.xticks(x, labels)
plt.legend()

# Add data labels on top of bars
for i in range(len(labels)):
    plt.text(x[i] - width/2, merge_sort_times[i] + max(merge_sort_times) * 0.01, f"{merge_sort_times[i]:.2f}", ha='center', va='bottom')
    plt.text(x[i] + width/2, quick_sort_times[i] + max(merge_sort_times) * 0.01, f"{quick_sort_times[i]:.2f}", ha='center', va='bottom')

plt.ylim(0, max(max(merge_sort_times), max(quick_sort_times)) + 100000)  # Adjust Y limit
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
cases = ['Best Case', 'Average Case', 'Worst Case']
python_times = [0.00200, 0.01640, 0.01590]
java_times = [0.00050, 0.00640, 0.00940]

# Position of bars on X-axis
x = np.arange(len(cases))
width = 0.35  # Width of the bars

# Plotting
plt.figure(figsize=(10, 6))
plt.bar(x - width/2, python_times, width, label='Python', color='skyblue', edgecolor='black')
plt.bar(x + width/2, java_times, width, label='Java', color='orange', edgecolor='black')

# Labels and title
plt.xlabel('Case')
plt.ylabel('Time (ms)')
plt.title('Binary Search Time Comparison(Python vs Java)')
plt.xticks(x, cases)
plt.legend()

# Add data labels on top of bars
for i in range(len(cases)):
    plt.text(x[i] - width/2, python_times[i] + 0.0005, f"{python_times[i]:.5f}", ha='center', va='bottom', fontsize=9)
    plt.text(x[i] + width/2, java_times[i] + 0.0005, f"{java_times[i]:.5f}", ha='center', va='bottom', fontsize=9)

plt.ylim(0, max(max(python_times), max(java_times)) + 0.005)  # Adjust y-axis limit for label spacing
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
import matplotlib.pyplot as plt

# Dataset sizes
data_sizes = [1000, 5000, 10000, 50000, 100000, 500000, 1000000, 5000000, 10000000, 50000000]

# Execution times in milliseconds
merge_py = [4.85, 32.50, 67.15, 465.69, 1021.62, 4770.02, 10343.22, 71328.33, 179124.88, 890195.77]
merge_java = [19, 62, 89, 244, 483, 2056, 3439, 22082, 58254, 497249]

# Create line plot
plt.figure(figsize=(12, 6))
plt.plot(data_sizes, merge_py, marker='o', label='Merge Sort (Python)', color='skyblue')
plt.plot(data_sizes, merge_java, marker='s', label='Merge Sort (Java)', color='orange')

# Labeling
plt.title('Merge Sort Time Comparison(Python vs Java)')
plt.xlabel('Dataset Size')
plt.ylabel('Time (ms)')
plt.legend()
plt.grid(True)
plt.xscale('log')  # Log scale for better readability
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Dataset sizes
data_sizes = [1000, 5000, 10000, 50000, 100000, 500000, 1000000, 5000000, 10000000, 50000000]

# Execution times in milliseconds
quick_py = [3.46, 22.82, 41.86, 322.48, 565.80, 3549.51, 7401.14, 44862.15, 103222.09, 735394.03]
quick_java = [21, 40, 65, 154, 264, 1425, 3356, 20781, 42517, 483405]

# Create line plot
plt.figure(figsize=(12, 6))
plt.plot(data_sizes, quick_py, marker='o', label='Quick Sort (Python)', color='skyblue')
plt.plot(data_sizes, quick_java, marker='s', label='Quick Sort (Java)', color='orange')

# Labeling
plt.title('Quick Sort Time Comparison(Python vs Java)')
plt.xlabel('Dataset Size')
plt.ylabel('Time (ms)')
plt.legend()
plt.grid(True)
plt.xscale('log')  # Log scale for better readability
plt.tight_layout()

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Dataset sizes
data_sizes = [1000, 5000, 10000, 50000, 100000, 500000, 1000000, 5000000, 10000000, 50000000]
py_best =   [0.00090, 0.00150, 0.00090, 0.00150, 0.00120, 0.00130, 0.00120, 0.00120, 0.00100, 0.00200]
java_best = [0.00080, 0.00160, 0.00190, 0.00120, 0.00090, 0.00080, 0.00080, 0.00060, 0.00070, 0.00050]

plt.figure(figsize=(10, 6))
plt.plot(data_sizes, py_best, marker='o', label='Python Best Case', color='skyblue')
plt.plot(data_sizes, java_best, marker='s', label='Java Best Case', color='orange')
plt.title('Best Case Search Time: Python vs Java')
plt.xlabel('Dataset Size')
plt.ylabel('Time (ms)')
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.tight_layout()
plt.show()

# %%
py_avg =   [0.00330, 0.00800, 0.00380, 0.01260, 0.00680, 0.00790, 0.00750, 0.00840, 0.00980, 0.01640]
java_avg = [0.00210, 0.00380, 0.01530, 0.00480, 0.00840, 0.00570, 0.00540, 0.00620, 0.01470, 0.00640]

plt.figure(figsize=(10, 6))
plt.plot(data_sizes, py_avg, marker='o', label='Python Average Case', color='skyblue')
plt.plot(data_sizes, java_avg, marker='s', label='Java Average Case', color='orange')
plt.title('Average Case Search Time: Python vs Java')
plt.xlabel('Dataset Size')
plt.ylabel('Time (ms)')
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.tight_layout()
plt.show()

# %%
py_worst =   [0.00210, 0.00280, 0.00370, 0.00550, 0.01280, 0.00650, 0.00710, 0.00730, 0.00860, 0.01590]
java_worst = [0.00140, 0.00230, 0.00490, 0.00450, 0.00280, 0.00490, 0.00450, 0.00520, 0.00590, 0.00940]

plt.figure(figsize=(10, 6))
plt.plot(data_sizes, py_worst, marker='o', label='Python Worst Case', color='skyblue')
plt.plot(data_sizes, java_worst, marker='s', label='Java Worst Case', color='orange')
plt.title('Worst Case Search Time: Python vs Java')
plt.xlabel('Dataset Size')
plt.ylabel('Time (ms)')
plt.legend()
plt.grid(True)
plt.xscale('log')
plt.tight_layout()
plt.show()
